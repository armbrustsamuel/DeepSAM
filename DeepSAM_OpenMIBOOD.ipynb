# %% [markdown]
# # OpenMIBOOD
#
# - dependencies: ISSUE
#   - `!pip install faiss-gpu` (not found in openmibood ) - replaced by `faiss-gpu-cu12`
#
# - download datasets: OK
#   - `tip`: run download multiple times, or remove the check exitance validation
#
# - run evaluation scripts:
#   - pending issues regarding dependencies

# %% [markdown]
# ## SETUP

# %%
# !git clone https://github.com/armbrustsamuel/OpenMIBOOD

# !cd /content/OpenMIBOOD/ && git pull
# Out:
# Cloning into 'OpenMIBOOD'...
# remote: Enumerating objects: 9618, done.
# remote: Counting objects: 100% (3004/3004), done.
# remote: Compressing objects: 100% (606/606), done.
# remote: Total 9618 (delta 2602), reused 2425 (delta 2398), pack-reused 6614 (from 3)
# Receiving objects: 100% (9618/9618), 82.11 MiB | 14.52 MiB/s, done.
# Resolving deltas: 100% (7107/7107), done.
# Already up to date.

# %% [markdown]
# ### Install dependencies (working version)

# %%
# !pip install torch>=1.13.1 torchvision>=0.13 scikit-learn json5 scipy matplotlib tqdm pyyaml>=5.4.1 pre-commit opencv-python>=4.4.0.46 imgaug>=0.4.0 pandas diffdist>=0.1 Cython>=0.29.30 faiss-gpu-cu12 faiss-cpu gdown>=4.7.1 nnunetv2==2.5.2 hd-bet==2.0.1 nibabel pydicom libmr>=0.1.9 torchio>=0.18.0 monai>=0.7.0 statsmodels # Adascale_postprocessor

# !pip install scikit-learn json5 scipy matplotlib tqdm pyyaml>=5.4.1 pre-commit opencv-python>=4.4.0.46 imgaug>=0.4.0 pandas diffdist>=0.1 Cython>=0.29.30 faiss-gpu-cu12 faiss-cpu gdown>=4.7.1 nnunetv2==2.5.2 hd-bet==2.0.1 nibabel pydicom libmr>=0.1.9 torchio>=0.18.0 monai>=0.7.0 statsmodels # Adascale_postprocessor

# !pip install numpy>=2.0.0

# !pip install -e /content/OpenMIBOOD
# !pip install faiss-gpu-cu12
# !pip install faiss-cpu


# Explanation about the faiss versions
# !pip install faiss-gpu>=1.7.2
# !pip install conda
# !conda install -c pytorch faiss-gpu

# $ pip install faiss-cpu
# # or:
# $ pip install faiss-gpu-cu12 # CUDA 12.x, Python 3.8+
# $ pip install faiss-gpu-cu11 # CUDA 11.x, Python 3.8+
# $ pip install faiss-gpu # Python 3.6-3.10 (legacy, no longer available after version 1.7.3)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.

# %% [markdown]
# ## DOWNLOAD DATASETS

# %%
# !cd /content/OpenMIBOOD/scripts/download/ && python download.py
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1lI1j0_fDDvjIt9JlWAw09X8ks-yrR_H1
# From (redirected): https://drive.google.com/uc?id=1lI1j0_fDDvjIt9JlWAw09X8ks-yrR_H1&confirm=t&uuid=26aa10a3-25a4-48b6-99b0-e59b31cc37b3
# To: /content/OpenMIBOOD/scripts/download/data/benchmark_imglist.zip
# 100% 28.0M/28.0M [00:01<00:00, 27.9MB/s]
# mnist needs download:
# ./data/images_classic/mnist
# Downloading...
# From (original): https://drive.google.com/uc?id=1CCHAGWqA1KJTFFswuF9cbhmB-j98Y1Sb
# From (redirected): https://drive.google.com/uc?id=1CCHAGWqA1KJTFFswuF9cbhmB-j98Y1Sb&confirm=t&uuid=d72c381a-8960-4bf2-8c41-63054ca24733
# To: /content/OpenMIBOOD/scripts/download/data/images_classic/mnist/mnist.zip
# 100% 47.2M/47.2M [00:00<00:00, 155MB/s]
# notmnist needs download:
# ./data/images_classic/notmnist
# Downloading...
# From (original): https://drive.google.com/uc?id=16ueghlyzunbksnc_ccPgEAloRW9pKO-K
# ...

# %% [markdown]
# ## TEST EVALUATION scripts

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_classifiers.py
# Out:
# ...
# 100% 90.0M/90.0M [00:34<00:00, 2.72MB/s]
# ...
# 100% 42.7M/42.7M [00:46<00:00, 965kB/s]
# ...
# 100% 120M/120M [01:48<00:00, 1.15MB/s]

# %% [markdown]
# #### Midog

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_midog_ccagt.py
# Out:
# 100% 3.31G/3.31G [03:49<00:00, 15.5MB/s]
# Extracting CCAgT subsets...: 100% 15/15 [00:12<00:00,  1.19it/s]
# CCAgT: Download complete
# Preprocessing CCAgT annotations...: 100% 63190/63190 [00:00<00:00, 509377.09it/s]
# Processing CCAgT annotations...: 100% 29675/29675 [10:12<00:00, 48.48it/s]
# CCAgT: Processing complete

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_midog_fnac2019.py
# Out:
# ##############################################################
# We will try to download the FNAC 2019 dataset automatically from https://1drv.ms/u/s!Al-T6d-_ENf6axsEbvhbEc2gUFs.
# If there are any errors with the automatic download, please visit the above link, download the file manually, move it to "tmp/fnac2019.zip", and run this script again.
# ##############################################################
# 100% 694M/694M [00:24<00:00, 29.2MB/s]
# FNAC2019: Download complete
# Processing images from subset B: 100% 99/99 [00:07<00:00, 12.72it/s]
# Processing images from subset M: 100% 113/113 [00:08<00:00, 13.87it/s]
# FNAC2019: Processing complete

# %%
# !cd /content/OpenMIBOOD/ && git pull
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_midog.py --download_path=/content/OpenMIBOOD/scripts/download/OpenMIBOOD/tmp/midog
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 770 bytes | 385.00 KiB/s, done.
# From https://github.com/armbrustsamuel/OpenMIBOOD
#    49d532f..a37365c  main       -> origin/main
# Updating 49d532f..a37365c
# Fast-forward
#  scripts/download/OpenMIBOOD/download_midog.py | 100 +++++++++++++-------------
#  1 file changed, 50 insertions(+), 50 deletions(-)
# ...
# MIDOG: Processing complete

# %%
# this execution takes around 1h (and can be executed in background - even if the connection drops)
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_midog.py --download_path=/content/OpenMIBOOD/scripts/download/OpenMIBOOD/tmp/midog
# Out:
# ...
# 100% 504/504 [2:32:31<00:00, 18.16s/it]
#
# Processing domain 1a...
#
# Processing domain 1b...
#
# Processing domain 1c...
#
# Processing domain 2...
#
# Processing domain 3...
#
# Processing domain 4...
#
# Processing domain 5...
#
# Processing domain 6a...
#
# Processing domain 6b...
#
# Processing domain 7...
# MIDOG: Processing complete

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py
# Out:
# 2025-06-17 12:57:28.726546: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-17 12:57:29.388774: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750165049.680154   45809 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750165049.762538   45809 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ##### Training new model
#
# worked with new Perceptual loss

# %% [markdown]
# ###### Perceptual loss com mean scores

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
import os
from PIL import Image
import torch.optim as optim

# Define the Autoencoder class with inplace=False for ReLU
class Autoencoder(nn.Module):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.GroupNorm(num_groups=128, num_channels=128),  # or 1 group per channel (i.e., InstanceNorm)
            # nn.GroupNorm(num_groups=32, num_channels=128),

            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.GroupNorm(num_groups=16, num_channels=64),
            nn.GroupNorm(num_groups=64, num_channels=64),  # or 1 group per channel (i.e., InstanceNorm)

            nn.Conv2d(64, latent_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Conv2d(latent_dim, latent_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.BatchNorm2d(latent_dim),

            nn.Conv2d(latent_dim, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.BatchNorm2d(64),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),

            nn.Conv2d(128, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Define the MIDOGDataset (assuming this is correct from your previous cells)
class MIDOGDataset(torch.utils.data.Dataset):
    def __init__(self, txt_file, root_dir, transform=None):
        """
        Args:
            txt_file (str): Path to the text file with image paths and labels.
            root_dir (str): Directory where the 1a folder is located.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.image_labels = []
        self.root_dir = root_dir
        self.transform = transform

        with open(txt_file, "r") as file:
            for line in file:
                path, label = line.strip().split()
                self.image_labels.append((path, int(label)))

    def __len__(self):
        return len(self.image_labels)

    def __getitem__(self, idx):
        rel_path, label = self.image_labels[idx]
        full_path = os.path.join(self.root_dir, rel_path)
        image = Image.open(full_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, label

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


####################################
# https://gist.github.com/spnova12/ab4aa294673eb5e1af0c99995ef68add
####################################

# class FeatureExtractor(nn.Module):
#       def __init__(self, cnn, feature_layer=11):
#           super(FeatureExtractor, self).__init__()
#           self.features = nn.Sequential(*list(cnn.features.children())[:(feature_layer + 1)])

#       def normalize(self, tensors, mean, std):
#           if not torch.is_tensor(tensors):
#               raise TypeError('tensor is not a torch image.')
#           for tensor in tensors:
#               for t, m, s in zip(tensor, mean, std):
#                   t.sub_(m).div_(s)
#           return tensors

#       def forward(self, x):
#           # it image is gray scale then make it to 3 channel
#           if x.size()[1] == 1:
#               x = x.expand(-1, 3, -1, -1)

#           # [-1: 1] image to  [0:1] image---------------------------------------------------(1)
#           x = (x + 1) * 0.5

#           # https://pytorch.org/docs/stable/torchvision/models.html
#           x.data = self.normalize(x.data, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#           return self.features(x)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # Feature extracting using vgg19
# vgg19_for_feature_extractor = torchvision.models.vgg19(pretrained=True)
# feature_extractor = FeatureExtractor(vgg19_for_feature_extractor, feature_layer=35).to(device)

# class VGG19Loss(object):
#     def __call__(self, output, target):

#         # [-1: 1] image to  [0:1] image---------------------------------------------------(2)
#         output = (output + 1) * 0.5
#         target = (target + 1) * 0.5

#         output = feature_extractor(output)
#         target = feature_extractor(target).data
#         return MSE(output, target)

# # # criterion
# MSE = nn.MSELoss().to(device)
# BCE = nn.BCELoss().to(device)
# # VGE = VGG19Loss()

####################################
####################################


import torch.nn.functional as F

class MultiLayerFeatureExtractor(nn.Module):
    def __init__(self, vgg_features_sequential, selected_layers):
        super().__init__()
        self.selected_layers = selected_layers
        # The 'vgg_features_sequential' argument is ALREADY the Sequential module containing the features.
        # We don't need to access '.features' again.
        self.vgg_layers = vgg_features_sequential
        self.layer_mapping = {
            'block1_conv1': 0,  'block1_conv2': 2,
            'block2_conv1': 5,  'block2_conv2': 7,
            'block3_conv1': 10, 'block3_conv2': 12, 'block3_conv3': 14, 'block3_conv4': 16,
            'block4_conv1': 19, 'block4_conv2': 21, 'block4_conv3': 23, 'block4_conv4': 25,
            'block5_conv1': 28, 'block5_conv2': 30, 'block5_conv3': 32, 'block5_conv4': 34,
        }

    def forward(self, x):
        features = []
        layer_indices_to_extract = [self.layer_mapping[l] for l in self.selected_layers]
        for name, layer in enumerate(self.vgg_layers):
            x = layer(x)
            if name in layer_indices_to_extract:
                features.append(x)
        return features

class PerceptualLoss(nn.Module):
    def __init__(self, vgg_features_sequential, selected_layers, selected_layer_weights):
        super().__init__()
        self.feature_extractor = MultiLayerFeatureExtractor(vgg_features_sequential, selected_layers)
        self.selected_layer_weights = selected_layer_weights

    def forward(self, input, recon):
        # Assume input and recon are in [0, 1], normalize to ImageNet stats
        mean = torch.tensor([0.485, 0.456, 0.406], device=input.device).view(1,3,1,1)
        std = torch.tensor([0.229, 0.224, 0.225], device=input.device).view(1,3,1,1)
        input_norm = (input - mean) / std
        recon_norm = (recon - mean) / std

        feats_input = self.feature_extractor(input_norm)
        feats_recon = self.feature_extractor(recon_norm)

        loss = 0.0
        for f1, f2, w in zip(feats_input, feats_recon, self.selected_layer_weights):
            loss += w * F.mse_loss(f1, f2)
        return loss


import torch
import torchvision.models as models

# --- VGG19 Perceptual Loss Setup ---
# This line correctly gets the 'features' Sequential module from VGG19
vgg19_features = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1).features.cuda().eval()
for param in vgg19_features.parameters():
    param.requires_grad = False

# 2. Define selected layers and weights
# selected_layers = ['block1_conv2', 'block2_conv2', 'block3_conv3']
# selected_layer_weights = [1.0, 0.75, 0.5]

selected_layers = ['block2_conv2',"block3_conv3",'block4_conv3']
selected_layer_weights = [2.0 , 4.0 , 8.0]

# 3. Instantiate the perceptual loss
# Pass the extracted features Sequential module directly
criterion = PerceptualLoss(vgg19_features, selected_layers, selected_layer_weights)

# 4. Use in your training loop
# Suppose input and recon are your model's input and output tensors
# loss = criterion(input, recon)
# loss.backward()


# Data preparation
transform = transforms.Compose([
    transforms.Resize((64, 64)), # Resize to match autoencoder input
    transforms.ToTensor(),
    # Note: Normalization for PerceptualLoss is done *inside* the loss function now.
    # You might still want normalization for the autoencoder itself,
    # depending on how your original Keras model handled it.
    # If your Keras model didn't have a specific normalization layer at the start,
    # you might remove the Normalize from here and decide if you need it
    # before feeding to the autoencoder.
    # For now, let's keep it simple and only normalize within the loss.
])


dataset = MIDOGDataset(
    txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/train_midog.txt",
    root_dir="/content/OpenMIBOOD/data/midog",
    transform=transform
)

dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# Model, Loss, Optimizer setup
latent_dim = 32
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the model using the corrected Autoencoder class
model = Autoencoder(latent_dim=latent_dim).to(device)

# Initialize the criterion using the corrected PerceptualLoss class
# criterion = PerceptualLoss().to(device) # Move criterion to the device -> ORIGINAL before I try to replicate my DeepSAM here
# criterion = VGG19Loss()

# optimizer = optim.Adam(model.parameters(), lr=1e-3) # Make sure optimizer is defined --> ORIGINAL before I try to replicate my DeepSAM here
optimizer = optim.Adam(model.parameters(), lr=1e-3) # Make sure optimizer is defined


# Training loop
num_epochs = 60

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for inputs, _ in dataloader:
        inputs = inputs.to(device) # Move data to device

        optimizer.zero_grad()
        outputs = model(inputs)

        # Calculate loss using the criterion
        # The inputs to criterion should be the original inputs and the autoencoder outputs
        # The criterion handles its own normalization and feature extraction internally.
        loss = criterion(inputs, outputs)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(dataloader):.4f}")
# Out:
# Epoch [1/100], Loss: 95.8904
# Epoch [2/100], Loss: 82.8693
# Epoch [3/100], Loss: 76.1677
# Epoch [4/100], Loss: 71.8069
# Epoch [5/100], Loss: 68.5486
# Epoch [6/100], Loss: 65.9367
# Epoch [7/100], Loss: 63.7168
# Epoch [8/100], Loss: 61.9068
# Epoch [9/100], Loss: 60.3643
# Epoch [10/100], Loss: 58.9504
# Epoch [11/100], Loss: 57.7574
# Epoch [12/100], Loss: 56.6799
# Epoch [13/100], Loss: 55.7215
# Epoch [14/100], Loss: 54.8558
# Epoch [15/100], Loss: 54.0311
# Epoch [16/100], Loss: 53.2860
# Epoch [17/100], Loss: 52.5716
# Epoch [18/100], Loss: 51.8731
# Epoch [19/100], Loss: 51.2907
# Epoch [20/100], Loss: 50.6573
# Epoch [21/100], Loss: 50.0498
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-7b49210b0f60> in <cell line: 0>()
#     275         # The inputs to criterion should be the original inputs and the autoencoder outputs
# ...

# %% [markdown]
# ###### Perceptual loss com scores separados para cada imagem

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
import os
from PIL import Image
import torch.optim as optim

# Define the Autoencoder class with inplace=False for ReLU
class Autoencoder(nn.Module):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim

        # # Encoder
        # self.encoder = nn.Sequential(
        #     nn.Conv2d(3, 128, kernel_size=3, stride=1, padding=1),  # 64x64x3 -> 64x64x128
        #     # nn.ReLU(),
        #     nn.ReLU(inplace=False),  # <-- Ensure inplace=False
        #     nn.MaxPool2d(kernel_size=2, stride=2, padding=0),       # 64x64x128 -> 32x32x128
        #     # nn.GroupNorm(num_groups=32, num_channels=128),         # GroupNorm with 32 groups
        #     nn.GroupNorm(num_groups=128, num_channels=128),  # or 1 group per channel (i.e., InstanceNorm)

        #     nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1), # 32x32x128 -> 32x32x64
        #     # nn.ReLU(),
        #     nn.ReLU(inplace=False),  # <-- Ensure inplace=False
        #     nn.MaxPool2d(kernel_size=2, stride=2, padding=0),       # 32x32x64 -> 16x16x64
        #     # nn.GroupNorm(num_groups=16, num_channels=64),          # GroupNorm with 16 groups
        #     nn.GroupNorm(num_groups=64, num_channels=64),  # or 1 group per channel (i.e., InstanceNorm)

        #     nn.Conv2d(64, latent_dim, kernel_size=3, stride=1, padding=1), # 16x16x64 -> 16x16xlatent_dim
        #     # nn.ReLU(),
        #     nn.ReLU(inplace=False),  # <-- Ensure inplace=False
        #     nn.MaxPool2d(kernel_size=2, stride=2, padding=0)        # 16x16xlatent_dim -> 8x8xlatent_dim
        # )

        # # Decoder
        # self.decoder = nn.Sequential(
        #     nn.Conv2d(latent_dim, latent_dim, kernel_size=3, stride=1, padding=1), # 8x8xlatent_dim -> 8x8xlatent_dim
        #     nn.ReLU(),
        #     nn.Upsample(scale_factor=2, mode='nearest'),                           # 8x8xlatent_dim -> 16x16xlatent_dim
        #     nn.BatchNorm2d(latent_dim),

        #     nn.Conv2d(latent_dim, 64, kernel_size=3, stride=1, padding=1),         # 16x16xlatent_dim -> 16x16x64
        #     nn.ReLU(),
        #     nn.Upsample(scale_factor=2, mode='nearest'),                           # 16x16x64 -> 32x32x64
        #     nn.BatchNorm2d(64),

        #     nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),                # 32x32x64 -> 32x32x128
        #     nn.ReLU(),
        #     nn.Upsample(scale_factor=2, mode='nearest'),                           # 32x32x128 -> 64x64x128

        #     nn.Conv2d(128, 3, kernel_size=3, stride=1, padding=1),                 # 64x64x128 -> 64x64x3
        #     nn.Sigmoid()
        # )

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.GroupNorm(num_groups=128, num_channels=128),  # or 1 group per channel (i.e., InstanceNorm)
            # nn.GroupNorm(num_groups=32, num_channels=128),

            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2),
            # nn.GroupNorm(num_groups=16, num_channels=64),
            nn.GroupNorm(num_groups=64, num_channels=64),  # or 1 group per channel (i.e., InstanceNorm)

            nn.Conv2d(64, latent_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.MaxPool2d(kernel_size=2, stride=2)
            # nn.GroupNorm(num_groups=32, num_channels=32),  # or 1 group per channel (i.e., InstanceNorm)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Conv2d(latent_dim, latent_dim, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.BatchNorm2d(latent_dim),

            nn.Conv2d(latent_dim, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.BatchNorm2d(64),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=False),  # <-- Ensure inplace=False
            nn.Upsample(scale_factor=2, mode='nearest'),

            nn.Conv2d(128, 3, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# Define the MIDOGDataset (assuming this is correct from your previous cells)
class MIDOGDataset(torch.utils.data.Dataset):
    def __init__(self, txt_file, root_dir, transform=None):
        """
        Args:
            txt_file (str): Path to the text file with image paths and labels.
            root_dir (str): Directory where the 1a folder is located.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.image_labels = []
        self.root_dir = root_dir
        self.transform = transform

        with open(txt_file, "r") as file:
            for line in file:
                path, label = line.strip().split()
                self.image_labels.append((path, int(label)))

    def __len__(self):
        return len(self.image_labels)

    def __getitem__(self, idx):
        rel_path, label = self.image_labels[idx]
        full_path = os.path.join(self.root_dir, rel_path)
        image = Image.open(full_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, label

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class MultiLayerFeatureExtractor(nn.Module):
    def __init__(self, vgg_features_sequential, selected_layers):
        super().__init__()
        self.selected_layers = selected_layers
        # The 'vgg_features_sequential' argument is ALREADY the Sequential module containing the features.
        # We don't need to access '.features' again.
        self.vgg_layers = vgg_features_sequential
        self.layer_mapping = {
            'block1_conv1': 0,  'block1_conv2': 2,
            'block2_conv1': 5,  'block2_conv2': 7,
            'block3_conv1': 10, 'block3_conv2': 12, 'block3_conv3': 14, 'block3_conv4': 16,
            'block4_conv1': 19, 'block4_conv2': 21, 'block4_conv3': 23, 'block4_conv4': 25,
            'block5_conv1': 28, 'block5_conv2': 30, 'block5_conv3': 32, 'block5_conv4': 34,
        }

    def forward(self, x):
        features = []
        layer_indices_to_extract = [self.layer_mapping[l] for l in self.selected_layers]
        for name, layer in enumerate(self.vgg_layers):
            x = layer(x)
            if name in layer_indices_to_extract:
                features.append(x)
        return features

class PerceptualLoss(nn.Module):
    def __init__(self, vgg_features_sequential, selected_layers, selected_layer_weights):
        super().__init__()
        self.feature_extractor = MultiLayerFeatureExtractor(vgg_features_sequential, selected_layers)
        self.selected_layer_weights = selected_layer_weights

    def forward(self, input, recon):
        mean = torch.tensor([0.485, 0.456, 0.406], device=input.device).view(1,3,1,1)
        std = torch.tensor([0.229, 0.224, 0.225], device=input.device).view(1,3,1,1)
        input_norm = (input - mean) / std
        recon_norm = (recon - mean) / std

        feats_input = self.feature_extractor(input_norm)
        feats_recon = self.feature_extractor(recon_norm)

        # Compute per-sample perceptual loss
        losses = []
        for f1, f2, w in zip(feats_input, feats_recon, self.selected_layer_weights):
            # # Compute per-sample MSE (no reduction)
            # mse = F.mse_loss(f1, f2, reduction='none')
            # # Average over all but batch dimension
            # mse = mse.view(mse.size(0), -1).mean(dim=1)

            # alternative to make equal to keras implementation
            mse = F.mse_loss(f1, f2, reduction='none')
            mse = mse.view(mse.size(0), -1).sum(dim=1) / 1e6

            losses.append(w * mse)
        # Sum weighted losses for each sample
        total_loss = sum(losses)
        return total_loss  # shape: (batch_size,)

import torch
import torchvision.models as models

# --- VGG19 Perceptual Loss Setup ---
# This line correctly gets the 'features' Sequential module from VGG19
vgg19_features = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1).features.cuda().eval()
for param in vgg19_features.parameters():
    param.requires_grad = False

# 2. Define selected layers and weights
# selected_layers = ['block1_conv2', 'block2_conv2', 'block3_conv3']
# selected_layer_weights = [1.0, 0.75, 0.5]


# Deeper layers: ['block3_conv4', 'block4_conv4', 'block5_conv4']
selected_layers = ['block3_conv4', 'block4_conv4', 'block5_conv4']
selected_layer_weights = [2.0 , 4.0 , 8.0]

#  Original layers (from tutorial)
# selected_layers = ['block2_conv2',"block3_conv3",'block4_conv3']
# selected_layer_weights = [1.0, 2.0, 4.0]

# 3. Instantiate the perceptual loss
# Pass the extracted features Sequential module directly
criterion = PerceptualLoss(vgg19_features, selected_layers, selected_layer_weights)

# 4. Use in your training loop
# Suppose input and recon are your model's input and output tensors
# loss = criterion(input, recon)
# loss.backward()

from torchvision import transforms

def contrast_stretching(tensor):
    # tensor: (C, H, W), values in [0, 1]
    min_val = tensor.amin(dim=(1,2), keepdim=True)
    max_val = tensor.amax(dim=(1,2), keepdim=True)
    stretched = (tensor - min_val) / (max_val - min_val + 1e-8)
    return stretched

# transform = transforms.Compose([
#     transforms.Resize((64, 64)),
#     transforms.ToTensor(),
#     transforms.Lambda(contrast_stretching),  # <-- Add contrast stretching here
# ])

# Data preparation
transform = transforms.Compose([
    transforms.Resize((64, 64)), # Resize to match autoencoder input
    transforms.ToTensor(),
    transforms.Lambda(contrast_stretching),  # <-- Add contrast stretching here
    # Note: Normalization for PerceptualLoss is done *inside* the loss function now.
    # You might still want normalization for the autoencoder itself,
    # depending on how your original Keras model handled it.
    # If your Keras model didn't have a specific normalization layer at the start,
    # you might remove the Normalize from here and decide if you need it
    # before feeding to the autoencoder.
    # For now, let's keep it simple and only normalize within the loss.
])


dataset = MIDOGDataset(
    txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/train_midog.txt",
    root_dir="/content/OpenMIBOOD/data/midog",
    transform=transform
)

dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# Model, Loss, Optimizer setup
latent_dim = 32
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the model using the corrected Autoencoder class
model = Autoencoder(latent_dim=latent_dim).to(device)

# Initialize the criterion using the corrected PerceptualLoss class
# criterion = PerceptualLoss().to(device) # Move criterion to the device -> ORIGINAL before I try to replicate my DeepSAM here
# criterion = VGG19Loss()

# optimizer = optim.Adam(model.parameters(), lr=1e-3) # Make sure optimizer is defined --> ORIGINAL before I try to replicate my DeepSAM here
optimizer = optim.Adam(model.parameters(), lr=5e-2) # Make sure optimizer is defined


# # Training loop
# num_epochs = 60

# for epoch in range(num_epochs):
#     model.train()
#     running_loss = 0.0

#     for inputs, _ in dataloader:
#         inputs = inputs.to(device) # Move data to device

#         optimizer.zero_grad()
#         outputs = model(inputs)

#         # Calculate loss using the criterion
#         # The inputs to criterion should be the original inputs and the autoencoder outputs
#         # The criterion handles its own normalization and feature extraction internally.
#         loss = criterion(inputs, outputs)

#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#     print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(dataloader):.4f}")

# Training loop
num_epochs = 2

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for inputs, _ in dataloader:
        inputs = inputs.to(device) # Move data to device

        optimizer.zero_grad()
        outputs = model(inputs)

        # Calculate loss using the criterion. This returns a tensor of shape (batch_size,)
        perceptual_losses_per_sample = criterion(inputs, outputs)

        # Reduce the loss to a scalar by taking the mean across the batch
        loss = perceptual_losses_per_sample.mean()
        # print("Average Perceptual Loss (Train):", loss.item())

        loss.backward()
        optimizer.step()

        running_loss += loss.item() # Use the scalar loss for accumulating


    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(dataloader):.4f}")
# Out:
# Epoch [1/2], Loss: 3.8394
# Epoch [2/2], Loss: 3.2920

# %%
# Save the model's state_dict
# !rm /content/autoencoder_model_60_epochs_1e-3_perceptual-samples-2.pth
torch.save(model.state_dict(), "/content/autoencoder_model_60_epochs_1e-3_perceptual-samples-2.pth")

# %%
# !cd /content/OpenMIBOOD/ && git pull
# !rm /content/OpenMIBOOD/results/midog/postprocessors/autoencoder.pkl
# Out:
# Already up to date.

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py --postprocessor autoencoder
# Out:
# 2025-06-17 16:15:16.865580: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-17 16:15:16.885840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750176916.908321  110707 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750176916.915113  110707 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ##### Save model

# %%
# Save the model's state_dict
torch.save(model.state_dict(), "/content/autoencoder_model_60_epochs_1e-3.pth")

# %%
# test_dataset = MIDOGDataset(
#     txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/test_midog.txt",
#     root_dir="/content/OpenMIBOOD/data/midog",
#     transform=transform
# )
# test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# model.eval()  # Set model to evaluation mode
# test_loss = 0.0

# with torch.no_grad():  # No gradients needed for evaluation
#     for inputs, _ in test_dataloader:
#         inputs = inputs.to(device)
#         outputs = model(inputs)
#         loss = criterion(outputs, inputs)
#         test_loss += loss.item()

# avg_test_loss = test_loss / len(test_dataloader)
# print(f"Test Loss: {avg_test_loss:.4f}")


test_dataset = MIDOGDataset(
    txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/test_midog.txt",
    root_dir="/content/OpenMIBOOD/data/midog",
    transform=transform
)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

model.eval()  # Set model to evaluation mode
test_loss = 0.0

with torch.no_grad():  # No gradients needed for evaluation
    for inputs, _ in test_dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, inputs)
        # loss is a tensor of shape (batch_size,), so sum it and get the scalar value
        test_loss += loss.sum().item()

avg_test_loss = test_loss / len(test_dataset) # Divide by the total number of samples
print(f"Test Loss: {avg_test_loss:.4f}")
# Out:
# Test Loss: 19.5556

# %%
# test_b1_dataset = MIDOGDataset(
#     txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/test_midog_1b.txt",
#     root_dir="/content/OpenMIBOOD/data/midog",
#     transform=transform
# )
# test_b1_dataloader = DataLoader(test_b1_dataset, batch_size=16, shuffle=False)

# model.eval()  # Set model to evaluation mode
# test_loss = 0.0

# with torch.no_grad():  # No gradients needed for evaluation
#     for inputs, _ in test_b1_dataloader:
#         inputs = inputs.to(device)
#         outputs = model(inputs)
#         loss = criterion(outputs, inputs)
#         test_loss += loss.item()

# avg_test_loss = test_loss / len(test_b1_dataloader)
# print(f"Test Loss: {avg_test_loss:.4f}")
test_b1_dataset = MIDOGDataset(
    txt_file="/content/OpenMIBOOD/data/benchmark_imglist/midog/test_midog_1b.txt",
    root_dir="/content/OpenMIBOOD/data/midog",
    transform=transform
)
test_b1_dataloader = DataLoader(test_b1_dataset, batch_size=16, shuffle=False)

model.eval()  # Set model to evaluation mode
test_loss = 0.0

with torch.no_grad():  # No gradients needed for evaluation
    for inputs, _ in test_b1_dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, inputs)
        # The loss is now a tensor of shape (batch_size,), sum it before adding to total
        test_loss += loss.sum().item()

# Divide by the total number of samples, not the number of batches
avg_test_loss = test_loss / len(test_b1_dataset)
print(f"Test Loss: {avg_test_loss:.4f}")
# Out:
# Test Loss: 19.1968

# %% [markdown]
# ##### Execute using my autoencoder

# %%
# !cd /content/OpenMIBOOD/ && git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 420 bytes | 420.00 KiB/s, done.
# From https://github.com/armbrustsamuel/OpenMIBOOD
#    11ad32b..449b198  main       -> origin/main
# Updating 11ad32b..449b198
# Fast-forward
#  openood/postprocessors/autoencoder_postprocessor.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !rm /content/OpenMIBOOD/results/midog/postprocessors/autoencoder.pkl

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py --postprocessor autoencoder
# Out:
# 2025-06-03 20:47:59.483713: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 20:47:59.502859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748983679.524360   91214 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748983679.530882   91214 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py --postprocessor autoencoder
# Out:
# 2025-06-03 17:52:38.804030: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 17:52:38.823283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748973158.844944   40852 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748973158.851459   40852 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py
# Out:
# 2025-06-03 17:54:18.707197: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 17:54:18.726261: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748973258.747794   41780 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748973258.754232   41780 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py --postprocessor ash
# Out:
# 2025-06-03 17:59:14.055688: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 17:59:14.076294: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748973554.098240   43522 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748973554.104791   43522 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ###### old weights

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_midog.py --postprocessor autoencoder
# Out:
# 2025-06-03 18:12:07.775438: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 18:12:07.795264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748974327.817340   47662 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748974327.823905   47662 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### Oasis

# %%
#  TODO: Download it manually
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_oasis3_atlas.py

# downloaded
# form filled
# Out:
# To acquire the ATLAS data, please visit https://fcon_1000.projects.nitrc.org/indi/retro/atlas.html and agree to their terms of use.
# Afterwards, follow the download instructions.
# After filling out the brief Google form at https://goo.gl/forms/KwCljKSLWbbHWalD2 and acquiring the decryption key, place the decrypted "ATLAS_R2.0.tar.gz" in the directory of this script and run this script again.
# Also, make sure that HD-BET (used for brain extraction) is installed (pip install hd-bet, to reproduce paper results, version 2.0.1 is required) and callable from the command line using "hd-bet".

# %%
#  TODO: Download it manually
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_oasis3_brats.py

# registered
# form filled
# Out:
# To acquire the BraTS 2023 data, please register at https://www.synapse.org/Synapse:syn51156910/wiki/627000 and fill out the data access form.
# After joining the data access team, download the "ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData.zip" file, place it in this script's directory, and rerun the script.

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_oasis3_chaos.py
# Out:
# ...
# 100% 1.02G/1.02G [10:46<00:00, 1.69MB/s]
# 100% 20/20 [00:03<00:00,  5.09it/s]
# CHAOS: Processing complete

# %%
# !cd /content/OpenMIBOOD/ && git pull

# /content/OpenMIBOOD/scripts/download/OpenMIBOOD/tmp/Task02_Heart.tar
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_oasis3_heart.py
# Out:
# Already up to date.
# Extracting Heart data from local file directory as download limit was reached...
# Heart: Processing complete

# %%
#  TODO: Download it manually
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_oasis3.py
# Out:
# To acquire the OASIS3 data, please request access at https://sites.wustl.edu/oasisbrains/home/access/. Only the access to OASIS-3: Longitudinal Multimodal Imaging is required.
# Continue to register a NITRC account using the same email at https://www.nitrc.org/account/register.php.
# After being granted access to the OASIS-3 data, log into your NITRC account and download the data.
# This process is not as straightforward as the other datasets, so please follow the instructions on the github repository.
# It comes down to selecting the following checkboxes: all sessions, T1w, T2w, and CT, download as zip archive, include project and subjects in file paths, simplify archive structure.
# After downloading the data, rename the resulting file to "OASIS3.zip", place it in the directory of this script and rerun it.
# ...

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_oasis3.py

# %% [markdown]
# #### Phakir (not yet available)

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir_cataracts.py
# Out:
# ...
# 100% 27.6G/27.6G [37:27<00:00, 13.2MB/s]
# CATARACTS: Processing complete

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir_cholec80.py

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir_endovis2018.py

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir_endovis2015.py

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir_kvasir.py

# %%
# !cd /content/OpenMIBOOD/scripts/ && python download/OpenMIBOOD/download_phakir.py

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_phakir.py

# %% [markdown]
# #### Others

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood_imagenet.py
# Out:
# 2025-05-20 14:00:14.769654: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-20 14:00:14.788702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747749614.810269   45571 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747749614.817172   45571 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cd /content/OpenMIBOOD/scripts/ && python eval_ood.py --root /content/OpenMIBOOD/
